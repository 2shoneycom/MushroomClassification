# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, GlobalAveragePooling2D
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.applications import VGG16
from tensorflow.keras.optimizers import Adam

# %%
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

# %%
# 경로 설정
data_dir = 'C:\\Users\\intel\\Downloads\\dataset'

# 데이터 증강 및 스케일링
datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.3  # 70% 훈련, 30% 검증+테스트
)

# 데이터 제너레이터 설정
train_generator = datagen.flow_from_directory(
    data_dir,
    target_size=(128, 128),
    batch_size=32,
    class_mode='categorical',
    subset='training'  # 70% 훈련 세트
)

validation_generator = datagen.flow_from_directory(
    data_dir,
    target_size=(128, 128),
    batch_size=32,
    class_mode='categorical',
    subset='validation'  # 30% 검증+테스트 세트
)
# Out:
# Found 54209 images belonging to 100 classes.
# Found 23164 images belonging to 100 classes.

# %%
# VGG16 모델 불러오기 (사전 학습된 가중치 사용, 마지막 분류 레이어 제외)
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(128, 128, 3))

# %%
# 간단한 모델 생성
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(256, activation='relu'),
    Dense(100, activation='softmax')  # 100개의 클래스로 분류
])

# 모든 층을 학습 가능하게 설정
for layer in base_model.layers:
    layer.trainable = True

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(
    train_generator,
    epochs=20,
    validation_data=validation_generator
)
# Out:
# Epoch 1/20
# 1695/1695 [==============================] - 484s 282ms/step - loss: 3.6805 - accuracy: 0.1736 - val_loss: 3.2126 - val_accuracy: 0.2424
# Epoch 2/20
# 1695/1695 [==============================] - 433s 255ms/step - loss: 3.0488 - accuracy: 0.2719 - val_loss: 2.8604 - val_accuracy: 0.3045
# Epoch 3/20
# 1695/1695 [==============================] - 431s 254ms/step - loss: 2.7825 - accuracy: 0.3158 - val_loss: 2.6492 - val_accuracy: 0.3376
# Epoch 4/20
# 1695/1695 [==============================] - 430s 254ms/step - loss: 2.5948 - accuracy: 0.3451 - val_loss: 2.5953 - val_accuracy: 0.3511
# Epoch 5/20
# 1695/1695 [==============================] - 430s 254ms/step - loss: 2.5084 - accuracy: 0.3633 - val_loss: 2.4295 - val_accuracy: 0.3774
# Epoch 6/20
# 1695/1695 [==============================] - 431s 254ms/step - loss: 2.3339 - accuracy: 0.3976 - val_loss: 2.2846 - val_accuracy: 0.4079
# Epoch 7/20
# 1695/1695 [==============================] - 433s 255ms/step - loss: 2.2441 - accuracy: 0.4162 - val_loss: 2.2628 - val_accuracy: 0.4134
# Epoch 8/20
# 1695/1695 [==============================] - 437s 258ms/step - loss: 2.1613 - accuracy: 0.4361 - val_loss: 2.0873 - val_accuracy: 0.4561
# Epoch 9/20
# 1695/1695 [==============================] - 447s 263ms/step - loss: 2.0851 - accuracy: 0.4499 - val_loss: 2.0432 - val_accuracy: 0.4641
# Epoch 10/20
# 1695/1695 [==============================] - 447s 264ms/step - loss: 2.0557 - accuracy: 0.4566 - val_loss: 2.1588 - val_accuracy: 0.4328
# Epoch 11/20
# 1695/1695 [==============================] - 445s 262ms/step - loss: 2.0122 - accuracy: 0.4667 - val_loss: 2.1106 - val_accuracy: 0.4529
# Epoch 12/20
# 1695/1695 [==============================] - 433s 255ms/step - loss: 1.9784 - accuracy: 0.4749 - val_loss: 2.1961 - val_accuracy: 0.4316
# Epoch 13/20
# 1695/1695 [==============================] - 434s 256ms/step - loss: 1.9605 - accuracy: 0.4800 - val_loss: 1.9383 - val_accuracy: 0.4836
# Epoch 14/20
# 1695/1695 [==============================] - 433s 256ms/step - loss: 1.9536 - accuracy: 0.4848 - val_loss: 1.9255 - val_accuracy: 0.4900
# Epoch 15/20
# 1695/1695 [==============================] - 431s 254ms/step - loss: 1.9175 - accuracy: 0.4884 - val_loss: 1.9233 - val_accuracy: 0.4877
# Epoch 16/20
# 1695/1695 [==============================] - 429s 253ms/step - loss: 1.9163 - accuracy: 0.4886 - val_loss: 2.0336 - val_accuracy: 0.4690
# Epoch 17/20
# 1695/1695 [==============================] - 437s 258ms/step - loss: 1.9010 - accuracy: 0.4916 - val_loss: 1.9389 - val_accuracy: 0.4904
# Epoch 18/20
# 1695/1695 [==============================] - 434s 256ms/step - loss: 1.8957 - accuracy: 0.4926 - val_loss: 1.9893 - val_accuracy: 0.4811
# Epoch 19/20
# 1695/1695 [==============================] - 437s 258ms/step - loss: 1.8951 - accuracy: 0.4940 - val_loss: 1.9320 - val_accuracy: 0.4872
# Epoch 20/20
# 1695/1695 [==============================] - 435s 256ms/step - loss: 1.8752 - accuracy: 0.4983 - val_loss: 1.9422 - val_accuracy: 0.4855

# %%
# 시각화
import matplotlib.pyplot as plt

accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy)+1)
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.legend()
plt.show()
